# %%
import matplotlib.pyplot as plt
import os 
import pandas as pd

# %% [markdown]
# #### Exercício 01 - Leia o lucro total de todos os meses e mostre-o usando um gráfico de linhas.

# %%
df = pd.read_csv("C:\\Users\\FIC\\Documents\\fundamentos-datapython-erika\\Arquivos\\company_sales_data.csv")
# visualizar o cabeçalho do data frame 
df.head()
# Out:
#    month_number  facecream  facewash  toothpaste  bathingsoap  shampoo  \
# 0             1       2500      1500        5200         9200     1200
# 1             2       2630      1200        5100         6100     2100
# 2             3       2140      1340        4550         9550     3550
# 3             4       3400      1130        5870         8870     1870
# 4             5       3600      1740        4560         7760     1560
#
#    moisturizer  total_units  total_profit
# 0         1500        21100        211000
# 1         1200        18330        183300
# 2         1340        22470        224700
# 3         1130        22270        222700
# 4         1740        20960        209600

# %% [markdown]
# ##### Arquivo: company_sales_data.csv
# ##### Dados de lucro total fornecidos para cada mês. O gráfico de linha gerado deve incluir as seguintes propriedades:
# #### Nome do rótulo X = Número do mês
# #### Nome do rótulo Y = lucro total

# %%
# Selecionar os dados que serão apresentados no grafico
listaLucro = df['total_profit'].to_list()
listaMeses = df['month_number'].to_list()

#Criando o grafico utilizando os daodos listados anteriormente
plt.plot(listaMeses,listaLucro, label = 'Lucro Mensal do Ano Anterior')
plt.xlabel('Número do mês') 
plt.ylabel("Lucro")
plt.title('Lucro Mensal da Empresa')# Titulo do grafico
plt.legend() # Legenda do grafico
